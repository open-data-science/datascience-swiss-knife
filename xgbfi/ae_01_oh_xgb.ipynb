# %%
from pprint import pprint
from collections import Counter

import pandas as pd
import numpy as np

from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder

from natsort import natsorted

import xgboost as xgb

# %%
df_questions = pd.read_excel('../data/voting outcomes/Questions.xlsx')
df_questions['Question ID'] = 'Q' + df_questions['Question ID'].astype(str)
df_questions.set_index('Question ID', inplace=1)
df_questions.head()
# Out:
#                                            Question Text Possible Answers
# Question ID
# Q96024                             Are you good at math?           Yes,No
# Q98059                     Do/did you have any siblings?   Yes,Only-child
# Q98078            Do you have a "go-to" creative outlet?           Yes,No
# Q98197       Do you pray or meditate on a regular basis?           Yes,No
# Q98578         Do you exercise 3 or more times per week?           Yes,No

# %%
df_train = pd.read_csv('../data/voting outcomes/train2016.csv')
df_test = pd.read_csv('../data/voting outcomes/test2016.csv')

df_train.shape, df_test.shape
# Out:
# ((5568, 108), (1392, 107))

# %%
party_encoder = LabelEncoder()
df_train.Party = party_encoder.fit_transform(df_train.Party)

# %%
TRAIN = 0
TEST = 1

df_train['source'] = TRAIN
df_test['source'] = TEST

df_all = pd.concat([df_train, df_test])

# %%
describe = df_all.YOB.describe(percentiles=[0.01, 0.99])
low = describe['1%']
high = describe['99%']

df_all.loc[(df_all.YOB < low) | (df_all.YOB > high), 'YOB'] = np.nan 
df_all.loc[df_all.YOB.isnull(), 'YOB'] = df_all.YOB.median()

# %%
all_columns = sorted(set(df_all.columns) - {'USER_ID', 'Party', 'source'})

categorical = [col for col in all_columns if df_all[col].dtype == 'O']
questions   = natsorted([q for q in categorical if q.startswith('Q')])
numerical   = [col for col in all_columns if df_all[col].dtype != 'O']

# %%
df_all.loc[:, categorical] = df_all.loc[:, categorical].fillna('na')

# %%
def clean_level_names(s):
    s = s.replace('$', '')
    s = s.replace(',', '')
    s = s.replace(' - ', '_')
    s = s.replace(' ', '_')
    return s

df_all.Income = df_all.Income.apply(clean_level_names)
df_all.HouseholdStatus = df_all.HouseholdStatus.str.replace(' ', '_')
df_all.EducationLevel = df_all.EducationLevel.str.replace(' ', '_')
df_all.Q117193 = df_all.Q117193.str.replace(' ', '_')
df_all.Q120194 = df_all.Q120194.str.replace(' ', '_')

df_all.Q98059  = df_all.Q98059.map({'yes': 'yes', 'only-child': 'no'})
df_all.Q99982  = df_all.Q99982.map({'check!': 'yes', 'nope': 'no'})
df_all.Q106997 = df_all.Q106997.map({'yay people!': 'yes', 'grrr people': 'no'})
df_all.Q108855 = df_all.Q108855.map({'yes!': 'yes', 'umm...': 'no'})
df_all.Q117186 = df_all.Q117186.map({'hot headed': 'yes', 'cool headed': 'no'})

# %%
records = df_all[categorical].to_dict(orient='records')
oh_vectorizer = DictVectorizer(separator='_')
oh = oh_vectorizer.fit_transform(records)

# %% [markdown]
# ## Other features

# %%
yes_no = set(df_questions[df_questions['Possible Answers'] == 'Yes,No'].index) 
yes_no = natsorted(yes_no | {'Q98059', 'Q99982', 'Q106997', 'Q108855', 'Q117186'})

# %%
answers_cnt = df_all[yes_no].apply(Counter, axis=1).apply(pd.Series).fillna(0)
answers_cnt.columns = ['%s_cnt' % c for c in answers_cnt.columns]

# %% [markdown]
# ## Models

# %%
train_idx = (df_all.source == TRAIN).values
test_idx = (df_all.source == TEST).values

df_train = df_all[df_all.source == TRAIN].reset_index(drop=1)
df_test = df_all[df_all.source == TEST].reset_index(drop=1)

X = np.hstack([oh[train_idx].toarray(),
               df_train[numerical], 
               answers_cnt[df_all.source == TRAIN]])

features = oh_vectorizer.get_feature_names() + \
            numerical + list(answers_cnt.columns)

y = df_train.Party

# %%
dtrain = xgb.DMatrix(X, label=y, feature_names=features, missing=np.nan)

# %%
results = []

# %%
early_stopping_rounds = 100
n_estimators = 1500

xgb_pars = {
    'eta': 0.01,
    'gamma': 6,
    'max_depth': 4,
    'min_child_weight': 1,
    'max_delta_step': 0,
    'subsample': 0.83,
    'colsample_bytree': 0.9,
    'colsample_bylevel': 1,
    'lambda': 1,
    'alpha': 0,
    'objective': 'binary:logistic',
    'eval_metric': 'error',
    'nthread': 4,
    'seed': 42
}

# %%
history = xgb.cv(xgb_pars, dtrain, num_boost_round=n_estimators, nfold=5, metrics=('error'), as_pandas=True,
                 show_progress=25, early_stopping_rounds=early_stopping_rounds)

score = 1 - history['test-error-mean'].iloc[-1]
results.append((score, len(history), dict(xgb_pars)))
score
# Out:
# Will train until cv error hasn't decreased in 100 rounds.
# [0]	cv-test-error:0.3969452+0.0163055711142	cv-train-error:0.3810874+0.00228461293002
# [25]	cv-test-error:0.3769992+0.0115983503551	cv-train-error:0.3698114+0.00540871092221
# [50]	cv-test-error:0.3762802+0.0118298687972	cv-train-error:0.364241+0.00427504306411
# [75]	cv-test-error:0.375921+0.0122744694712	cv-train-error:0.3616802+0.00519134088266
# [100]	cv-test-error:0.373585+0.0122720345664	cv-train-error:0.3573224+0.0038104469869
# [125]	cv-test-error:0.3716082+0.0127645078464	cv-train-error:0.3515274+0.00337665133527
# [150]	cv-test-error:0.3710694+0.0123585177202	cv-train-error:0.3442496+0.00207632363566
# [175]	cv-test-error:0.367655+0.0130127309355	cv-train-error:0.3398472+0.00180803488904
# [200]	cv-test-error:0.368194+0.0113137476196	cv-train-error:0.3336478+0.00243397102694
# [225]	cv-test-error:0.3685534+0.0122062000082	cv-train-error:0.3300092+0.00314269326534
# [250]	cv-test-error:0.3708894+0.0121262004206	cv-train-error:0.3256964+0.00269175783458
# [275]	cv-test-error:0.3685534+0.0122058908499	cv-train-error:0.3203054+0.00153683956222
# [300]	cv-test-error:0.3665766+0.0124235393604	cv-train-error:0.315319+0.000903095786725
# [325]	cv-test-error:0.3667564+0.0117476064728	cv-train-error:0.3098834+0.00150729872288
# [350]	cv-test-error:0.365319+0.0111440045406	cv-train-error:0.3084456+0.00191334436001
# [375]	cv-test-error:0.3628034+0.00925734254741	cv-train-error:0.304717+0.00288192574505
# [400]	cv-test-error:0.3642408+0.0100468599552	cv-train-error:0.3023812+0.00282110201163
# [425]	cv-test-error:0.3646002+0.00934438846367	cv-train-error:0.2986522+0.00416536698983
# [450]	cv-test-error:0.3678348+0.00753019945021	cv-train-error:0.2951482+0.00328576514072
# Stopping. Best iteration:
# [373] cv-mean:0.362444	cv-std:0.00985215302358
# 0.63755600000000001

# %%
for score, ntrees, pars in reversed(results[-5:]):
    print score, ntrees, pars
# Out:
# 0.637556 374 {'colsample_bytree': 0.9, 'eval_metric': 'error', 'colsample_bylevel': 1, 'eta': 0.01, 'max_delta_step': 0, 'nthread': 4, 'min_child_weight': 1, 'subsample': 0.83, 'seed': 42, 'objective': 'binary:logistic', 'alpha': 0, 'max_depth': 4, 'gamma': 6, 'lambda': 1}

# %%
score, ntrees, best_pars = max(results, key=lambda x: x[0])
print score, ntrees
pprint(pars)
# Out:
# 0.637556 374
# {'alpha': 0,
#  'colsample_bylevel': 1,
#  'colsample_bytree': 0.9,
#  'eta': 0.01,
#  'eval_metric': 'error',
#  'gamma': 6,
#  'lambda': 1,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'nthread': 4,
#  'objective': 'binary:logistic',
#  'seed': 42,
#  'subsample': 0.83}

# %%
xgb_model = xgb.train(best_pars, dtrain, num_boost_round=ntrees, 
                      evals=[(dtrain, 'train')], verbose_eval=25)
# Out:
# [0]	train-error:0.384698
# [25]	train-error:0.374641
# [50]	train-error:0.371947
# [75]	train-error:0.369253
# [100]	train-error:0.364045
# [125]	train-error:0.358118
# [150]	train-error:0.351473
# [175]	train-error:0.348060
# [200]	train-error:0.341954
# [225]	train-error:0.338721
# [250]	train-error:0.336566
# [275]	train-error:0.332974
# [300]	train-error:0.328484
# [325]	train-error:0.323455
# [350]	train-error:0.320762
# [373]	train-error:0.316810

# %% [markdown]
# Now dump the model for xgbfi

# %%
def create_feature_map(fmap_filename, features):
    outfile = open(fmap_filename, 'w')
    for i, feat in enumerate(features):
        outfile.write('{0}\t{1}\tq\n'.format(i, feat))
    outfile.close()

create_feature_map('xgb.fmap', features)

# %%
# !head xgb.fmap
# Out:
# 0	EducationLevel_Associate's_Degree	q
# 1	EducationLevel_Bachelor's_Degree	q
# 2	EducationLevel_Current_K-12	q
# 3	EducationLevel_Current_Undergraduate	q
# 4	EducationLevel_Doctoral_Degree	q
# 5	EducationLevel_High_School_Diploma	q
# 6	EducationLevel_Master's_Degree	q
# 7	EducationLevel_na	q
# 8	Gender_Female	q
# 9	Gender_Male	q

# %%
xgb_model.dump_model('xgb.dump', fmap='xgb.fmap', with_stats=True)
# !head -n 30 xgb.dump
# Out:
# booster[0]:
# 0:[Q109244_Yes<0.5] yes=1,no=2,missing=1,gain=258.432,cover=1165.25
# 	1:[Q115611_Yes<0.5] yes=3,no=4,missing=3,gain=86.9162,cover=974
# 		3:[Q98197_Yes<0.5] yes=7,no=8,missing=7,gain=36.4256,cover=732.5
# 			7:[Gender_Male<0.5] yes=15,no=16,missing=15,gain=16.659,cover=596.25
# 				15:leaf=-0.00404933,cover=242.25
# 				16:leaf=-0.000647887,cover=354
# 			8:[Q108617_No<0.5] yes=17,no=18,missing=17,gain=10.3826,cover=136.25
# 				17:leaf=-0.000613497,cover=39.75
# 				18:leaf=0.0054359,cover=96.5
# 		4:[Q113181_Yes<0.5] yes=9,no=10,missing=9,gain=11.9666,cover=241.5
# 			9:[Q123464_No<0.5] yes=19,no=20,missing=19,gain=11.1044,cover=133
# 				19:leaf=-0.000481928,cover=40.5
# 				20:leaf=0.0057754,cover=92.5
# 			10:[YOB<1979.5] yes=21,no=22,missing=21,gain=16.1934,cover=108.5
# 				21:leaf=0.00470588,cover=58.5
# 				22:leaf=0.012549,cover=50
# 	2:[Q118232_Idealist<0.5] yes=5,no=6,missing=5,gain=6.0877,cover=191.25
# 		5:leaf=-0.0104687,cover=127
# 		6:[YOB<1995.5] yes=13,no=14,missing=13,gain=3.05724,cover=64.25
# 			13:leaf=-0.0155752,cover=55.5
# 			14:[Q116797_Yes<0.5] yes=27,no=28,missing=27,gain=7.20926,cover=8.75
# 				27:leaf=-0.0122581,cover=6.75
# 				28:leaf=0.00666667,cover=2
# booster[1]:
# 0:[Q109244_Yes<0.5] yes=1,no=2,missing=1,gain=276.58,cover=1160.99
# 	1:[Q113181_Yes<0.5] yes=3,no=4,missing=3,gain=84.1802,cover=975.495
# 		3:[Q115611_Yes<0.5] yes=7,no=8,missing=7,gain=30.1085,cover=709.998
# 			7:[Gender_Male<0.5] yes=15,no=16,missing=15,gain=17.8539,cover=574.999
# 				15:leaf=-0.00380136,cover=232.249

# %% [markdown]
# ## Submission

# %%
X_test = np.hstack([oh[test_idx].toarray(),
               df_test[numerical], 
               answers_cnt[df_all.source == TEST]])

dtest = xgb.DMatrix(X_test, feature_names=features)

y_pred = xgb_model.predict(dtest)
y_pred = (y_pred > 0.5).astype(int)
y_pred = party_encoder.inverse_transform(y_pred)

# %%
user_ids = df_test.USER_ID.values

result = pd.DataFrame({'USER_ID': user_ids, 'Predictions': y_pred})
result.to_csv('xgb3.csv', index=False)

# %% [markdown]
# - Public leaderboard score: 0.62787
# - Need better cv (now: 0.62787 lb vs 0.63755 cv)
#
# ## XGB fi

# %% [markdown]
# Let's have a look at xgbfi's output

# %%
# !mono ~/tmp/soft/xgbfi/bin/XgbFeatureInteractions.exe -m xgb.dump
# Out:
# =********************************
# * XGBOOST Feature Interactions *
# ********************************
#
# Settings:
# =========
# XgbModelFile: xgb.dump
# OutputXlsxFile: XgbFeatureInteractions.xlsx
# MaxInteractionDepth: 2
# MaxDeepening: -1
# MaxTrees: 100
# TopK: 100
# SortBy: Gain
# MaxHistograms: 10
#
# Parsing xgb.dump
# Constructing tree #1 => depth: 4 (23 nodes)
# Constructing tree #2 => depth: 4 (27 nodes)
# Constructing tree #3 => depth: 4 (23 nodes)
# Constructing tree #4 => depth: 4 (23 nodes)
# Constructing tree #5 => depth: 4 (23 nodes)
# Constructing tree #6 => depth: 4 (23 nodes)
# Constructing tree #7 => depth: 4 (25 nodes)
# Constructing tree #8 => depth: 4 (17 nodes)
# Constructing tree #9 => depth: 4 (21 nodes)
# Constructing tree #10 => depth: 4 (23 nodes)
# Constructing tree #11 => depth: 4 (23 nodes)
# Constructing tree #12 => depth: 4 (17 nodes)
# Constructing tree #13 => depth: 4 (21 nodes)
# Constructing tree #14 => depth: 4 (25 nodes)
# Constructing tree #15 => depth: 4 (27 nodes)
# Constructing tree #16 => depth: 4 (23 nodes)
# Constructing tree #17 => depth: 4 (23 nodes)
# Constructing tree #18 => depth: 4 (21 nodes)
# Constructing tree #19 => depth: 4 (27 nodes)
# Constructing tree #20 => depth: 4 (19 nodes)
# Constructing tree #21 => depth: 4 (17 nodes)
# Constructing tree #22 => depth: 4 (25 nodes)
# Constructing tree #23 => depth: 4 (21 nodes)
# Constructing tree #24 => depth: 4 (17 nodes)
# Constructing tree #25 => depth: 4 (17 nodes)
# Constructing tree #26 => depth: 4 (27 nodes)
# Constructing tree #27 => depth: 4 (21 nodes)
# Constructing tree #28 => depth: 4 (23 nodes)
# Constructing tree #29 => depth: 4 (23 nodes)
# Constructing tree #30 => depth: 4 (25 nodes)
# Constructing tree #31 => depth: 4 (29 nodes)
# Constructing tree #32 => depth: 4 (23 nodes)
# Constructing tree #33 => depth: 4 (23 nodes)
# Constructing tree #34 => depth: 4 (23 nodes)
# Constructing tree #35 => depth: 4 (23 nodes)
# Constructing tree #36 => depth: 4 (19 nodes)
# Constructing tree #37 => depth: 4 (25 nodes)
# Constructing tree #38 => depth: 4 (19 nodes)
# Constructing tree #39 => depth: 4 (21 nodes)
# Constructing tree #40 => depth: 4 (21 nodes)
# Constructing tree #41 => depth: 4 (23 nodes)
# Constructing tree #42 => depth: 4 (21 nodes)
# Constructing tree #43 => depth: 4 (23 nodes)
# Constructing tree #44 => depth: 4 (21 nodes)
# Constructing tree #45 => depth: 4 (21 nodes)
# Constructing tree #46 => depth: 4 (21 nodes)
# Constructing tree #47 => depth: 4 (25 nodes)
# Constructing tree #48 => depth: 4 (21 nodes)
# Constructing tree #49 => depth: 4 (17 nodes)
# Constructing tree #50 => depth: 4 (21 nodes)
# Constructing tree #51 => depth: 4 (19 nodes)
# Constructing tree #52 => depth: 4 (17 nodes)
# Constructing tree #53 => depth: 4 (19 nodes)
# Constructing tree #54 => depth: 4 (23 nodes)
# Constructing tree #55 => depth: 4 (25 nodes)
# Constructing tree #56 => depth: 4 (17 nodes)
# Constructing tree #57 => depth: 4 (17 nodes)
# Constructing tree #58 => depth: 4 (19 nodes)
# Constructing tree #59 => depth: 4 (25 nodes)
# Constructing tree #60 => depth: 4 (21 nodes)
# Constructing tree #61 => depth: 4 (17 nodes)
# Constructing tree #62 => depth: 4 (27 nodes)
# Constructing tree #63 => depth: 4 (25 nodes)
# Constructing tree #64 => depth: 4 (23 nodes)
# Constructing tree #65 => depth: 4 (23 nodes)
# Constructing tree #66 => depth: 4 (21 nodes)
# Constructing tree #67 => depth: 4 (21 nodes)
# Constructing tree #68 => depth: 4 (21 nodes)
# Constructing tree #69 => depth: 4 (21 nodes)
# Constructing tree #70 => depth: 4 (15 nodes)
# Constructing tree #71 => depth: 4 (21 nodes)
# Constructing tree #72 => depth: 4 (21 nodes)
# Constructing tree #73 => depth: 4 (17 nodes)
# Constructing tree #74 => depth: 4 (17 nodes)
# Constructing tree #75 => depth: 4 (21 nodes)
# Constructing tree #76 => depth: 4 (23 nodes)
# Constructing tree #77 => depth: 4 (17 nodes)
# Constructing tree #78 => depth: 4 (21 nodes)
# Constructing tree #79 => depth: 4 (21 nodes)
# Constructing tree #80 => depth: 4 (21 nodes)
# Constructing tree #81 => depth: 4 (25 nodes)
# Constructing tree #82 => depth: 4 (23 nodes)
# Constructing tree #83 => depth: 4 (21 nodes)
# Constructing tree #84 => depth: 4 (17 nodes)
# Constructing tree #85 => depth: 4 (29 nodes)
# Constructing tree #86 => depth: 4 (23 nodes)
# Constructing tree #87 => depth: 4 (29 nodes)
# Constructing tree #88 => depth: 4 (15 nodes)
# Constructing tree #89 => depth: 4 (19 nodes)
# Constructing tree #90 => depth: 4 (21 nodes)
# Constructing tree #91 => depth: 4 (21 nodes)
# Constructing tree #92 => depth: 4 (19 nodes)
# Constructing tree #93 => depth: 4 (21 nodes)
# Constructing tree #94 => depth: 4 (23 nodes)
# Constructing tree #95 => depth: 4 (19 nodes)
# Constructing tree #96 => depth: 4 (27 nodes)
# Constructing tree #97 => depth: 4 (21 nodes)
# Constructing tree #98 => depth: 4 (23 nodes)
# Constructing tree #99 => depth: 4 (23 nodes)
# Constructing tree #100 => depth: 4 (17 nodes)
# 100 trees has been constructed.
#
# Collectiong feature interactions up to depth 2
# Collectiong feature interactions within tree #1 => number of interactions: 28
# Collectiong feature interactions within tree #2 => number of interactions: 31
# Collectiong feature interactions within tree #3 => number of interactions: 26
# Collectiong feature interactions within tree #4 => number of interactions: 28
# Collectiong feature interactions within tree #5 => number of interactions: 28
# Collectiong feature interactions within tree #6 => number of interactions: 26
# Collectiong feature interactions within tree #7 => number of interactions: 28
# Collectiong feature interactions within tree #8 => number of interactions: 18
# Collectiong feature interactions within tree #9 => number of interactions: 26
# Collectiong feature interactions within tree #10 => number of interactions: 26
# Collectiong feature interactions within tree #11 => number of interactions: 26
# Collectiong feature interactions within tree #12 => number of interactions: 21
# Collectiong feature interactions within tree #13 => number of interactions: 23
# Collectiong feature interactions within tree #14 => number of interactions: 31
# Collectiong feature interactions within tree #15 => number of interactions: 32
# Collectiong feature interactions within tree #16 => number of interactions: 28
# Collectiong feature interactions within tree #17 => number of interactions: 29
# Collectiong feature interactions within tree #18 => number of interactions: 26
# Collectiong feature interactions within tree #19 => number of interactions: 32
# Collectiong feature interactions within tree #20 => number of interactions: 20
# Collectiong feature interactions within tree #21 => number of interactions: 21
# Collectiong feature interactions within tree #22 => number of interactions: 31
# Collectiong feature interactions within tree #23 => number of interactions: 25
# Collectiong feature interactions within tree #24 => number of interactions: 21
# Collectiong feature interactions within tree #25 => number of interactions: 18
# Collectiong feature interactions within tree #26 => number of interactions: 35
# Collectiong feature interactions within tree #27 => number of interactions: 22
# Collectiong feature interactions within tree #28 => number of interactions: 29
# Collectiong feature interactions within tree #29 => number of interactions: 29
# Collectiong feature interactions within tree #30 => number of interactions: 30
# Collectiong feature interactions within tree #31 => number of interactions: 38
# Collectiong feature interactions within tree #32 => number of interactions: 26
# Collectiong feature interactions within tree #33 => number of interactions: 26
# Collectiong feature interactions within tree #34 => number of interactions: 28
# Collectiong feature interactions within tree #35 => number of interactions: 29
# Collectiong feature interactions within tree #36 => number of interactions: 23
# Collectiong feature interactions within tree #37 => number of interactions: 32
# Collectiong feature interactions within tree #38 => number of interactions: 23
# Collectiong feature interactions within tree #39 => number of interactions: 26
# Collectiong feature interactions within tree #40 => number of interactions: 26
# Collectiong feature interactions within tree #41 => number of interactions: 28
# Collectiong feature interactions within tree #42 => number of interactions: 26
# Collectiong feature interactions within tree #43 => number of interactions: 29
# Collectiong feature interactions within tree #44 => number of interactions: 23
# Collectiong feature interactions within tree #45 => number of interactions: 26
# Collectiong feature interactions within tree #46 => number of interactions: 26
# Collectiong feature interactions within tree #47 => number of interactions: 31
# Collectiong feature interactions within tree #48 => number of interactions: 25
# Collectiong feature interactions within tree #49 => number of interactions: 18
# Collectiong feature interactions within tree #50 => number of interactions: 26
# Collectiong feature interactions within tree #51 => number of interactions: 23
# Collectiong feature interactions within tree #52 => number of interactions: 21
# Collectiong feature interactions within tree #53 => number of interactions: 20
# Collectiong feature interactions within tree #54 => number of interactions: 27
# Collectiong feature interactions within tree #55 => number of interactions: 31
# Collectiong feature interactions within tree #56 => number of interactions: 21
# Collectiong feature interactions within tree #57 => number of interactions: 18
# Collectiong feature interactions within tree #58 => number of interactions: 23
# Collectiong feature interactions within tree #59 => number of interactions: 31
# Collectiong feature interactions within tree #60 => number of interactions: 25
# Collectiong feature interactions within tree #61 => number of interactions: 21
# Collectiong feature interactions within tree #62 => number of interactions: 33
# Collectiong feature interactions within tree #63 => number of interactions: 29
# Collectiong feature interactions within tree #64 => number of interactions: 29
# Collectiong feature interactions within tree #65 => number of interactions: 28
# Collectiong feature interactions within tree #66 => number of interactions: 24
# Collectiong feature interactions within tree #67 => number of interactions: 26
# Collectiong feature interactions within tree #68 => number of interactions: 23
# Collectiong feature interactions within tree #69 => number of interactions: 26
# Collectiong feature interactions within tree #70 => number of interactions: 18
# Collectiong feature interactions within tree #71 => number of interactions: 26
# Collectiong feature interactions within tree #72 => number of interactions: 26
# Collectiong feature interactions within tree #73 => number of interactions: 21
# Collectiong feature interactions within tree #74 => number of interactions: 20
# Collectiong feature interactions within tree #75 => number of interactions: 23
# Collectiong feature interactions within tree #76 => number of interactions: 26
# Collectiong feature interactions within tree #77 => number of interactions: 21
# Collectiong feature interactions within tree #78 => number of interactions: 25
# Collectiong feature interactions within tree #79 => number of interactions: 26
# Collectiong feature interactions within tree #80 => number of interactions: 26
# Collectiong feature interactions within tree #81 => number of interactions: 32
# Collectiong feature interactions within tree #82 => number of interactions: 28
# Collectiong feature interactions within tree #83 => number of interactions: 26
# Collectiong feature interactions within tree #84 => number of interactions: 21
# Collectiong feature interactions within tree #85 => number of interactions: 38
# Collectiong feature interactions within tree #86 => number of interactions: 29
# Collectiong feature interactions within tree #87 => number of interactions: 38
# Collectiong feature interactions within tree #88 => number of interactions: 18
# Collectiong feature interactions within tree #89 => number of interactions: 23
# Collectiong feature interactions within tree #90 => number of interactions: 26
# Collectiong feature interactions within tree #91 => number of interactions: 26
# Collectiong feature interactions within tree #92 => number of interactions: 23
# Collectiong feature interactions within tree #93 => number of interactions: 26
# Collectiong feature interactions within tree #94 => number of interactions: 29
# Collectiong feature interactions within tree #95 => number of interactions: 23
# Collectiong feature interactions within tree #96 => number of interactions: 35
# Collectiong feature interactions within tree #97 => number of interactions: 26
# Collectiong feature interactions within tree #98 => number of interactions: 29
# Collectiong feature interactions within tree #99 => number of interactions: 29
# Collectiong feature interactions within tree #100 => number of interactions: 20
# 897 feature interactions has been collected.
#
# Writing XgbFeatureInteractions.xlsx
# Writing feature interactions with depth 0
# Writing feature interactions with depth 1
# Writing feature interactions with depth 2
# Writing leaf statistics
# Writing split value histograms
# XgbFeatureInteractions.xlsx has been written.
# Elapsed Time: 00:00:00.2636240
# >

# %% [markdown]
# ### Most important features:

# %%
interactions1 = pd.read_excel('XgbFeatureInteractions.xlsx', sheetname=0)
var_name = interactions1.Interaction.str.split('_').apply(lambda x: x[0])
interactions1['Question'] = df_questions.loc[var_name.head(15)]['Question Text'].reset_index(drop=1)
interactions1[['Question', 'Interaction', 'Gain']].head(n=15)
# Out:
#                                              Question  \
# 0                                 Are you a feminist?
# 1                        Do you personally own a gun?
# 2         Do you meditate or pray on a regular basis?
# 3                                 Are you a feminist?
# 4         Do you pray or meditate on a regular basis?
# 5         Do you pray or meditate on a regular basis?
# 6                                 Are you a feminist?
# 7                                                 NaN
# 8                                                 NaN
# 9                        Do you personally own a gun?
# 10        Do you meditate or pray on a regular basis?
# 11                                                NaN
# 12  Have you ever had your life genuinely threaten...
# 13                                                NaN
# 14   Which parent "wore the pants" in your household?
#
#                          Interaction         Gain
# 0                        Q109244_Yes  11213.11650
# 1                        Q115611_Yes   2920.23189
# 2                        Q113181_Yes   1895.89385
# 3                         Q109244_No   1241.84704
# 4                         Q98197_Yes    747.61359
# 5                          Q98197_No    614.38254
# 6                         Q109244_na    529.48820
# 7                                YOB    406.38478
# 8                        Gender_Male    333.88193
# 9                         Q115611_No    307.14925
# 10                        Q113181_No    284.25314
# 11  HouseholdStatus_Married_(w/kids)    247.73626
# 12                       Q118233_Yes    238.74904
# 13                           Yes_cnt    207.36418
# 14                       Q101163_Mom    189.01217

# %% [markdown]
# ### Most important 2nd order interactions:

# %%
interactions2 = pd.read_excel('XgbFeatureInteractions.xlsx', sheetname=1)
features2 = interactions2.Interaction.str.split('|', expand=True).applymap(lambda x: x.split('_')[0])
interactions2['Q1'] = df_questions['Question Text'].loc[features2[0]].reset_index(drop=1)
interactions2['Q2'] = df_questions['Question Text'].loc[features2[1]].reset_index(drop=1)
interactions2[['Q1', 'Q2', 'Interaction', 'Gain']].head(n=25)
# Out:
#                                                   Q1  \
# 0                                Are you a feminist?
# 1                                Are you a feminist?
# 2        Do you meditate or pray on a regular basis?
# 3                                Are you a feminist?
# 4                                Are you a feminist?
# 5                       Do you personally own a gun?
# 6                                Are you a feminist?
# 7                                Are you a feminist?
# 8                       Do you personally own a gun?
# 9                                Are you a feminist?
# 10                               Are you a feminist?
# 11       Do you meditate or pray on a regular basis?
# 12                               Are you a feminist?
# 13       Do you meditate or pray on a regular basis?
# 14       Do you meditate or pray on a regular basis?
# 15                                               NaN
# 16                                               NaN
# 17                               Are you a feminist?
# 18  Which parent "wore the pants" in your household?
# 19                               Are you a feminist?
# 20                               Are you a feminist?
# 21                               Are you a feminist?
# 22                                               NaN
# 23                      Do you personally own a gun?
# 24                               Are you a feminist?
#
#                                                    Q2  \
# 0                        Do you personally own a gun?
# 1         Do you meditate or pray on a regular basis?
# 2                        Do you personally own a gun?
# 3                                                 NaN
# 4        Are you more of an idealist or a pragmatist?
# 5         Do you pray or meditate on a regular basis?
# 6         Do you pray or meditate on a regular basis?
# 7                                 Are you a feminist?
# 8         Do you pray or meditate on a regular basis?
# 9   Your generally preferred approach to starting ...
# 10        Do you pray or meditate on a regular basis?
# 11                       Do you personally own a gun?
# 12                                                NaN
# 13                                                NaN
# 14  Have you ever had your life genuinely threaten...
# 15                                Are you a feminist?
# 16                       Do you personally own a gun?
# 17        Do you meditate or pray on a regular basis?
# 18                       Do you personally own a gun?
# 19        Do you pray or meditate on a regular basis?
# 20  Your generally preferred approach to starting ...
# 21                           Do you have any phobias?
# 22        Do you pray or meditate on a regular basis?
# 23  Do you have more than $20 cash in your wallet ...
# 24                       Do you personally own a gun?
#
#                                 Interaction        Gain
# 0                   Q109244_Yes|Q115611_Yes  8569.44020
# 1                   Q109244_Yes|Q113181_Yes  5667.52070
# 2                   Q113181_Yes|Q115611_Yes  3830.48367
# 3                       Q109244_Yes|Yes_cnt  3473.48018
# 4              Q109244_Yes|Q118232_Idealist  2220.05294
# 5                    Q115611_Yes|Q98197_Yes  1523.20387
# 6                      Q109244_No|Q98197_No  1144.33162
# 7                     Q109244_na|Q109244_No  1123.51510
# 8                     Q115611_Yes|Q98197_No   866.81459
# 9           Q109244_Yes|Q120194_Study_first   849.00979
# 10                   Q109244_Yes|Q98197_Yes   665.85570
# 11                   Q113181_Yes|Q115611_No   636.95818
# 12                          Q109244_Yes|YOB   537.00405
# 13                          Q113181_Yes|YOB   459.48564
# 14                  Q113181_Yes|Q118233_Yes   425.95938
# 15  EducationLevel_Current_K-12|Q109244_Yes   417.43342
# 16                  Gender_Male|Q115611_Yes   417.11700
# 17                    Q109244_No|Q113181_No   410.51540
# 18                  Q101163_Dad|Q115611_Yes   401.02361
# 19                     Q109244_na|Q98197_No   387.76620
# 20            Q109244_Yes|Q120194_Try_first   368.03047
# 21                   Q109244_Yes|Q112478_No   321.02780
# 22                   Gender_Male|Q98197_Yes   314.08230
# 23                  Q115611_Yes|Q122770_Yes   296.33928
# 24                   Q109244_No|Q115611_Yes   292.80580

# %% [markdown]
# ### 3rd level interaction

# %%
interactions3 = pd.read_excel('XgbFeatureInteractions.xlsx', sheetname=2)
features3 = interactions3.Interaction.str.split('|', expand=True).applymap(lambda x: x.split('_')[0])
interactions3['Q1'] = df_questions['Question Text'].loc[features3[0]].reset_index(drop=1)
interactions3['Q2'] = df_questions['Question Text'].loc[features3[1]].reset_index(drop=1)
interactions3['Q3'] = df_questions['Question Text'].loc[features3[2]].reset_index(drop=1)
interactions3[['Q1', 'Q2', 'Q3', 'Interaction', 'Gain']].head(n=15)
# Out:
#                                                    Q1  \
# 0                                 Are you a feminist?
# 1                                 Are you a feminist?
# 2                                 Are you a feminist?
# 3                                 Are you a feminist?
# 4                                 Are you a feminist?
# 5         Do you meditate or pray on a regular basis?
# 6                                 Are you a feminist?
# 7    Which parent "wore the pants" in your household?
# 8                                 Are you a feminist?
# 9         Do you meditate or pray on a regular basis?
# 10                                Are you a feminist?
# 11                                Are you a feminist?
# 12                                                NaN
# 13  Do you own any power tools? (power saws, drill...
# 14                                                NaN
#
#                                               Q2  \
# 0    Do you meditate or pray on a regular basis?
# 1                   Do you personally own a gun?
# 2    Do you pray or meditate on a regular basis?
# 3    Do you meditate or pray on a regular basis?
# 4                   Do you personally own a gun?
# 5                   Do you personally own a gun?
# 6                   Do you personally own a gun?
# 7                            Are you a feminist?
# 8    Do you meditate or pray on a regular basis?
# 9                   Do you personally own a gun?
# 10  Are you more of an idealist or a pragmatist?
# 11                  Do you personally own a gun?
# 12                  Do you personally own a gun?
# 13   Do you meditate or pray on a regular basis?
# 14   Do you meditate or pray on a regular basis?
#
#                                                    Q3  \
# 0                        Do you personally own a gun?
# 1         Do you pray or meditate on a regular basis?
# 2                                                 NaN
# 3                        Do you personally own a gun?
# 4         Do you pray or meditate on a regular basis?
# 5                                                 NaN
# 6         Do you pray or meditate on a regular basis?
# 7                        Do you personally own a gun?
# 8   Have you ever had your life genuinely threaten...
# 9   Would you say most of the hardship in your lif...
# 10                                                NaN
# 11  Do you have more than $20 cash in your wallet ...
# 12        Do you pray or meditate on a regular basis?
# 13                       Do you personally own a gun?
# 14                       Do you personally own a gun?
#
#                                           Interaction         Gain
# 0                 Q109244_Yes|Q113181_Yes|Q115611_Yes  12448.91936
# 1                  Q109244_Yes|Q115611_Yes|Q98197_Yes   4480.82507
# 2                      Q109244_Yes|Q98197_Yes|Yes_cnt   2270.39460
# 3                  Q109244_Yes|Q113181_Yes|Q115611_No   2114.83758
# 4                   Q109244_Yes|Q115611_Yes|Q98197_No   1641.82820
# 5                         Q113181_Yes|Q115611_Yes|YOB   1567.31121
# 6                    Q109244_No|Q115611_Yes|Q98197_No   1483.30854
# 7                 Q101163_Dad|Q109244_Yes|Q115611_Yes   1229.28380
# 8                 Q109244_Yes|Q113181_Yes|Q118233_Yes   1117.80319
# 9       Q113181_Yes|Q115611_Yes|Q115899_Circumstances   1030.10118
# 10                   Q109244_Yes|Q118232_Idealist|YOB    998.35082
# 11                Q109244_Yes|Q115611_Yes|Q122770_Yes    954.28818
# 12                 Gender_Male|Q115611_Yes|Q98197_Yes    860.97100
# 13                 Q106272_No|Q113181_Yes|Q115611_Yes    849.62400
# 14  HouseholdStatus_Married_(w/kids)|Q113181_Yes|Q...    812.02362
